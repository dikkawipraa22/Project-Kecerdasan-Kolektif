# %% [markdown]
# ### Import Library

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import joblib

# %% [markdown]
# ### Import Data

# %%
data = pd.read_csv('dataset/dataset.csv')
data
# Out:
#       id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0      0       1  0.85247  0.71826  0.57227        240               239
# 1      0       1  0.76686  0.69481  0.53966        234               233
# 2      0       1  0.85083  0.67604  0.58982        232               231
# 3      1       0  0.41121  0.79672  0.59257        178               177
# 4      1       0  0.32790  0.79782  0.53028        236               235
# ..   ...     ...      ...      ...      ...        ...               ...
# 751  250       0  0.80903  0.56355  0.28385        417               416
# 752  250       0  0.16084  0.56499  0.59194        415               413
# 753  251       0  0.88389  0.72335  0.46815        381               380
# 754  251       0  0.83782  0.74890  0.49823        340               339
# 755  251       0  0.81304  0.76471  0.46374        340               339
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Columns: 755 entries, id to class
# dtypes: float64(749), int64(6)
# memory usage: 4.4 MB

# %%
data.describe()
# Out:
#                id      gender         PPE         DFA        RPDE   numPulses  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   125.500000    0.515873    0.746284    0.700414    0.489058  323.972222
# std     72.793721    0.500079    0.169294    0.069718    0.137442   99.219059
# min      0.000000    0.000000    0.041551    0.543500    0.154300    2.000000
# 25%     62.750000    0.000000    0.762833    0.647053    0.386537  251.000000
# 50%    125.500000    1.000000    0.809655    0.700525    0.484355  317.000000
# 75%    188.250000    1.000000    0.834315    0.754985    0.586515  384.250000
# max    251.000000    1.000000    0.907660    0.852640    0.871230  907.000000
#
#        numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  \
# count        756.000000        756.000000          756.000000    756.000000
# mean         322.678571          0.006360            0.000383      0.002324
# ...

# %%
data['class'].value_counts()
# Out:
# class
# 1    564
# 0    192
# Name: count, dtype: int64

# %% [markdown]
# ### Preprocessinng Data

# %% [markdown]
# ##### Seleksi Fitur

# %%
data = data.drop(columns= ['id'])
data
# Out:
#      gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0         1  0.85247  0.71826  0.57227        240               239
# 1         1  0.76686  0.69481  0.53966        234               233
# 2         1  0.85083  0.67604  0.58982        232               231
# 3         0  0.41121  0.79672  0.59257        178               177
# 4         0  0.32790  0.79782  0.53028        236               235
# ..      ...      ...      ...      ...        ...               ...
# 751       0  0.80903  0.56355  0.28385        417               416
# 752       0  0.16084  0.56499  0.59194        415               413
# 753       0  0.88389  0.72335  0.46815        381               380
# 754       0  0.83782  0.74890  0.49823        340               339
# 755       0  0.81304  0.76471  0.46374        340               339
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# ...

# %% [markdown]
# ##### Cek Missing Value

# %%
data.isna().sum()
# Out:
# gender                       0
# PPE                          0
# DFA                          0
# RPDE                         0
# numPulses                    0
#                             ..
# tqwt_kurtosisValue_dec_33    0
# tqwt_kurtosisValue_dec_34    0
# tqwt_kurtosisValue_dec_35    0
# tqwt_kurtosisValue_dec_36    0
# class                        0
# Length: 754, dtype: int64

# %% [markdown]
# ##### Pemisahan Fitur dan Target

# %%
X = data.drop(columns='class')
y = data['class']
y.to_csv('dataset/target.csv', index=False, header=['class'])

# %% [markdown]
# ##### Normalisasi Data

# %%
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
df_X_normalized = pd.DataFrame(X_normalized, columns=X.columns)
joblib.dump(scaler, 'model scaling/minmax_scaler_model.pkl')
# Out:
# ['model scaling/minmax_scaler_model.pkl']

# %%
df_X_normalized
# Out:
#      gender       PPE       DFA      RPDE  numPulses  numPeriodsPulses  \
# 0       1.0  0.936278  0.565310  0.583000   0.262983          0.263274
# 1       1.0  0.837434  0.489455  0.537514   0.256354          0.256637
# 2       1.0  0.934385  0.428738  0.607479   0.254144          0.254425
# 3       0.0  0.426804  0.819111  0.611315   0.194475          0.194690
# 4       0.0  0.330615  0.822669  0.524431   0.258564          0.258850
# ..      ...       ...       ...       ...        ...               ...
# 751     0.0  0.886123  0.064857  0.180701   0.458564          0.459071
# 752     0.0  0.137730  0.069515  0.610436   0.456354          0.455752
# 753     0.0  0.972555  0.581775  0.437769   0.418785          0.419248
# 754     0.0  0.919363  0.664424  0.479726   0.373481          0.373894
# 755     0.0  0.890753  0.715566  0.431618   0.373481          0.373894
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# ...

# %%
df_X_normalized.describe()
# Out:
#            gender         PPE         DFA        RPDE   numPulses  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000
# mean     0.515873    0.813677    0.507582    0.466932    0.355770
# std      0.500079    0.195465    0.225523    0.191710    0.109634
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.832784    0.334970    0.323933    0.275138
# 50%      1.000000    0.886844    0.507941    0.460373    0.348066
# 75%      1.000000    0.915317    0.684108    0.602869    0.422376
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  \
# count        756.000000        756.000000          756.000000    756.000000
# mean           0.355839          0.391667            0.107243      0.076777
# std            0.109959          0.168203            0.209580      0.095425
# ...

# %%
df_X_normalized.to_csv('dataset/fitur.csv', index=False)
